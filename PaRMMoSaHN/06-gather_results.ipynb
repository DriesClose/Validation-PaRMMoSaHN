# %%
model_folder="05-automatic_curations/02-annotations/models"
output_folder="06-final_models"

# %% [markdown]
# ### Copying final models to the output folder

# %%
mkdir -p $output_folder
cp $model_folder/* $output_folder/

# %% [markdown]
# ### Convert models to popular formats

# %%
find $output_folder -type f | xargs -t -I % python utils/convert_model.py %
# Out:
# python utils/convert_model.py 06-final_models/C_acetobutylicum-adapt_gapfilled.xml
# '' is not a valid SBML 'SId'.
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-09-26
# python utils/convert_model.py 06-final_models/C_beijerinckii_13821-adapt_gapfilled.xml
# '' is not a valid SBML 'SId'.
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-09-26
# python utils/convert_model.py 06-final_models/C_beijerinckii_791-adapt_gapfilled.xml
# '' is not a valid SBML 'SId'.
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-09-26
